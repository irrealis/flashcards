# %%
from sympy import init_session
init_session()
# %matplotlib inline
# Out:
# IPython console for SymPy 1.3 (Python 3.7.0-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at http://docs.sympy.org/1.3/

# %%
plot(-sqrt(-x))

# %%
plot(sqrt(x))

# %%
def f(x): return sy.sqrt(x**2 + x + 1) - sy.sqrt(x**2 - x)

# %%
sy.plot_implicit(sy.Eq(y, f(x)), (x, -3, 3), (y, -2, 2))

# %%
3-2**0.5
# Out:
# 1.5857864376269049

# %%
def f(x): return x*sy.sqrt(x)

# %%
sy.diff(f(x), x)
# Out:
# 3⋅√x
# ────
#  2

# %%
def tl(x): return 3/2*x - 1/2

# %%
def nl(x): return -2/3*x + 5/3

# %%
sy.plot(f(x), tl(x), nl(x), (x, -6, 6), ylim=(-4, 4))

# %%
def f(t): return t**3 - 12*t**2 + 36*t

# %%
f(t)
# Out:
#  3       2
# t  - 12⋅t  + 36⋅t

# %%
diff(f(t))
# Out:
#    2
# 3⋅t  - 24⋅t + 36

# %%
def f1(t): return 3*t**2 - 24*t + 36

# %%
f1(2)
# Out:
# 0

# %%
f(3)
# Out:
# 27

# %%
f1(3)
# Out:
# -9

# %%
f(2)
# Out:
# 32

# %%
f(6)
# Out:
# 0

# %%
f(8)
# Out:
# 32

# %%
8**3
# Out:
# 512

# %%
12*8**2
# Out:
# 768

# %%
diff(diff(f(t)))
# Out:
# 6⋅t - 24

# %%
def f2(t): return 6*t - 24

# %%
f2(t)
# Out:
# 6⋅t - 24

# %%
f2(3)
# Out:
# -6

# %%
def f(x): return (2*x**2 + 4*x + 8)/sy.sqrt(x)
def g(x): return (2*sy.Pow(x, sy.Rational(3,2)) + 4*sy.Pow(x, sy.Rational(1,2)) + 8*sy.Pow(x, sy.Rational(-1,2)))

# %%
sy.powsimp(f(x))
# Out:
#    2
# 2⋅x  + 4⋅x + 8
# ──────────────
#       √x

# %%
g(x)
# Out:
#    3/2          8
# 2⋅x    + 4⋅√x + ──
#                 √x

# %%
simplify(sy.Eq(f(x),g(x)))
# Out:
# True

# %%
diff(g(x))
# Out:
#        2     4
# 3⋅√x + ── - ────
#        √x    3/2
#             x

# %%
def f(x): return x**2 - 8*x + 1
def f1(x): return 2*x - 8
def l0(x): return x/6 - sy.Rational(5,6)
def n0(x): return x/6 - sy.Rational(37,6)

# %%
diff(f(x)), f1(x)
# Out:
# (2⋅x - 8, 2⋅x - 8)

# %%
l0(x), n0(x)
# Out:
# ⎛x   5  x   37⎞
# ⎜─ - ─, ─ - ──⎟
# ⎝6   6  6   6 ⎠

# %%
f1(1), sy.Rational(-1, f1(1))
# Out:
# (-6, 1/6)

# %%
f(1), f1(1), n0(1)
# Out:
# (-6, -6, -6.0)

# %%
sy.plot(f(x), l0(x), n0(x), (x, -10, 20), ylim = (-15, 5))

# %%
f(x), f(1), diff(f(x)), f1(x), f1(1)
# Out:
# ⎛ 2                                    ⎞
# ⎝x  - 8⋅x + 1, -6, 2⋅x - 8, 2⋅x - 8, -6⎠

# %%
sy.solve(sy.Eq(x - 6*y, 5), y)
# Out:
# ⎡x   5⎤
# ⎢─ - ─⎥
# ⎣6   6⎦

# %%
sy.solve(sy.Eq(f1(x), sy.Rational(1,6)), x)
# Out:
# ⎡49⎤
# ⎢──⎥
# ⎣12⎦

# %%
f1(sy.Rational(49, 12))
# Out:
# 1/6

# %%
def tl0(x): return sy.Rational(1,6)*(x - sy.Rational(49,12)) + f(sy.Rational(49,12))
def tl1(x): return (-6)*(x - sy.Rational(49,12)) + f(sy.Rational(49,12))
#def tl(x): return -6*(x - sy.Rational(49,12)) + f(sy.Rational(49,12))

# %%
sy.simplify(f(sy.Rational(49,12)))
# Out:
# -2159
# ──────
#  144

# %%
sy.simplify(sy.Rational(7**4, 3**2 * 2**4) - sy.Rational(2 * 7**2, 3) + 1)
# Out:
# -2159
# ──────
#  144

# %%
sy.simplify(tl1(x))
# Out:
#        1369
# -6⋅x + ────
#        144

# %%
sy.Rational(1,6), -1/sy.Rational(1,6)
# Out:
# (1/6, -6)

# %%
tl0(x), tl1(x)
# Out:
# ⎛x   2257         1369⎞
# ⎜─ - ────, -6⋅x + ────⎟
# ⎝6   144          144 ⎠

# %%
f(sy.Rational(49, 12)), tl0(sy.Rational(49, 12)), tl1(sy.Rational(49, 12))
# Out:
# ⎛-2159   -2159   -2159 ⎞
# ⎜──────, ──────, ──────⎟
# ⎝ 144     144     144  ⎠

# %%
sy.plot(f(x), l0(x), n0(x), (x, -10, 20), ylim = (-15, 5))

# %%
sy.plot(2*x, -x/2, (x, -6, 6), ylim = (-4, 4))

# %%
sy.plot(f(x), tl(x))

# %%
49/12
# Out:
# 4.083333333333333
